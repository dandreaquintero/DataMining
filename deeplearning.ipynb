# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
# from IPython.display import set_matplotlib_formats
# set_matplotlib_formats('retina')
import seaborn as sns

from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# c:\Users\dandr\anaconda3\envs\mining\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\dandr\anaconda3\envs\mining\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\dandr\anaconda3\envs\mining\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
def load_data(data_path):
    data = []
    labels = []

    for bird_folder in os.listdir(data_path):
        bird_path = os.path.join(data_path, bird_folder)
        # print(bird_path)
        # print(bird_folder)

        if os.path.isdir(bird_path):
            for file in os.listdir(bird_path):
                file_path = os.path.join(bird_path, file)
                print(file_path)

                if file_path.endswith('.h5'):
                    with h5py.File(file_path, 'r') as hf:
                        spectrogram_data = np.array(hf['file'])  # Adjust the dataset name
                        data.append(spectrogram_data)
                        labels.append(bird_folder)

    return np.array(data), np.array(labels)

# %%
data_path = r'C:\Users\dandr\Documents\DataMining\FinalProject\spects_h5'
data= load_data(data_path)

# Split the data into training and testing sets
#X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

#train_images, test_images, train_labels, test_labels = train_test_split(X, y, test_size=10000, random_state=1)
# Out:
# C:\Users\dandr\Documents\DataMining\FinalProject\spects_h5\Acrocephalus arundinaceus\XC417157_0.h5
# C:\Users\dandr\Documents\DataMining\FinalProject\spects_h5\Acrocephalus arundinaceus\XC417157_1.h5
# C:\Users\dandr\Documents\DataMining\FinalProject\spects_h5\Acrocephalus arundinaceus\XC417157_2.h5
# C:\Users\dandr\Documents\DataMining\FinalProject\spects_h5\Acrocephalus arundinaceus\XC417157_3.h5
# C:\Users\dandr\Documents\DataMining\FinalProject\spects_h5\Acrocephalus arundinaceus\XC417157_4.h5
# C:\Users\dandr\Documents\DataMining\FinalProject\spects_h5\Acrocephalus arundinaceus\XC417157_5.h5
# C:\Users\dandr\Documents\DataMining\FinalProject\spects_h5\Acrocephalus arundinaceus\XC417158_0.h5
# C:\Users\dandr\Documents\DataMining\FinalProject\spects_h5\Acrocephalus arundinaceus\XC417158_1.h5
# C:\Users\dandr\Documents\DataMining\FinalProject\spects_h5\Acrocephalus arundinaceus\XC417158_10.h5
# ...

# %%
data
